# %% [markdown]
# # Exprement results of style token

# %% [markdown]
# ## cusent

# %%
# %pylab inline
import librosa
import librosa.display
from IPython.display import Audio
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from IPython.display import Image

# %% [markdown]
# text:ci3-taam3-gok3-gaa1-gei1-mat6-dik1-on3-gin2
# reference_audio:/home/gyzhang/speech_database/CUSENT/CUSENT_wav/train/cn01m/1.wav
# comments:text and reference are the same
# duration:3.03s speaking rate: 9/3.03=2.97
# 刺探国家机密的案件

# %%
Audio(filename="/home/gyzhang/speech_database/CUSENT/CUSENT_wav/newtrain/cn01m/1.wav",rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(filename="/home/gyzhang/projects/gst-tacotron/logs-tacotron/cusent/eval-154000_ref-1.wav",rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Image(filename="/home/gyzhang/projects/gst-tacotron/logs-tacotron/cusent/eval-154000_ref-1-align.png")

# %% [markdown]
# ci3-taam3-maa5-tau4-gei1-mat6-dik1-on3-gin2
# 刺探码头机密的案件

# %%
Audio(filename="/home/gyzhang/projects/gst-tacotron/logs-tacotron/cusent/eval-154000_ref-1.wav",rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Image(filename="/home/gyzhang/projects/gst-tacotron/logs-tacotron/cusent/eval-154000_ref-1-align.png")

# %% [markdown]
# text:wai4-ngo5-mun4-zaam6-mou4-pang4-geoi3-zi2-zing3-taa1
# reference_audio:/home/gyzhang/speech_database/CUSENT/CUSENT_wav/test/cnf4f/482.wav
# speaker:**cnf4f**
# comments:text and reference are the same  text set
# 唯我們暫無憑據指証他

# %%
Audio(filename="/home/gyzhang/speech_database/CUSENT/CUSENT_wav/newtest/cnf4f/482.wav",rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(filename="/home/gyzhang/projects/gst-tacotron/logs-tacotron/cusent/eval-154000_ref-482.wav",rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Image(filename="/home/gyzhang/projects/gst-tacotron/logs-tacotron/cusent/eval-154000_ref-482-align.png")

# %% [markdown]
# ### text:wai4-ngo5-mun4-zaam6-mou4-pang4-geoi3-zi2-zing3-taa1 | 唯我們暫無憑據指証他
# reference_audio:/home/gyzhang/speech_database/CUSENT/CUSENT_wav/newtrain/cn01m/1.wav
# speaker:**cn01m**
# duration:3.48 speaking rate: 10/3.48=2.87
# comments:text and speaker are different

# %% [markdown]
# **reference audio**

# %%
Audio(filename="/home/gyzhang/speech_database/CUSENT/CUSENT_wav/newtrain/cn01m/1.wav",rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **original audio**

# %%
Audio(filename="/home/gyzhang/speech_database/CUSENT/CUSENT_wav/newtest/cnf4f/482.wav",rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **generated audio**

# %%
Audio(filename="/home/gyzhang/projects/gst-tacotron/logs-tacotron/cusent/eval-154000_ref-1.wav",rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **align image**

# %%
Image(filename="/home/gyzhang/projects/gst-tacotron/logs-tacotron/cusent/eval-154000_ref-1-align.png")

# %% [markdown]
# ### text:gau2-luk6-lin4-zoi6-dong1-dei6-bei6-hung3-faan6-duk6-zeoi6
# reference_audio:/home/gyzhang/speech_database/CUSENT/CUSENT_wav/test/cnf6f/282.wav
# refernece_audio duration: 4.69s 11/4.49=2.345
# speaker:**cnf6f**
# comments:text and speaker are same in text domain

# %% [markdown]
# **original audio**

# %%
Audio(filename="/home/gyzhang/speech_database/CUSENT/CUSENT_wav/newtest/cnf6f/282.wav",rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **reference audio**

# %%
Audio(filename="/home/gyzhang/speech_database/CUSENT/CUSENT_wav/newtest/cnf4f/482.wav",rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(filename="/home/gyzhang/projects/gst-tacotron/logs-tacotron/cusent/eval-154000_ref-482.wav",rate=16000)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
